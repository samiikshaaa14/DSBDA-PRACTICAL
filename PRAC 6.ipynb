# %%
Create a Linear Regression Model using Python to predict home prices using Boston
Housing Dataset. The Boston Housing dataset contains information about various houses
in Boston through different parameters. There are 506 samples and 14 feature variables
in this dataset.

# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#loading dataset
df = pd.read_csv('HousingData.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.notnull()
# Out:
#      CRIM    ZN  INDUS  CHAS   NOX    RM    AGE   DIS   RAD   TAX  PTRATIO  \
# 0    True  True   True  True  True  True   True  True  True  True     True
# 1    True  True   True  True  True  True   True  True  True  True     True
# 2    True  True   True  True  True  True   True  True  True  True     True
# 3    True  True   True  True  True  True   True  True  True  True     True
# 4    True  True   True  True  True  True   True  True  True  True     True
# ..    ...   ...    ...   ...   ...   ...    ...   ...   ...   ...      ...
# 501  True  True   True  True  True  True   True  True  True  True     True
# 502  True  True   True  True  True  True   True  True  True  True     True
# 503  True  True   True  True  True  True   True  True  True  True     True
# 504  True  True   True  True  True  True   True  True  True  True     True
# 505  True  True   True  True  True  True  False  True  True  True     True
#
#         B  LSTAT  MEDV
# 0    True   True  True
# ...

# %%
#Define the independent and dependent variables from the dataset
X = df.iloc[:,0:13]
y = df.iloc[:,-1]

# %%
#Splitting data into traing and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=42)

# %%
#Shapes of the training and testing dataset
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404,)
# (102,)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 4
#       2 from sklearn.pipeline import make_pipeline
#       3 model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
# ----> 4 model.fit(X_train, y_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
# ...

# %%
model.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 model.score(X_test,y_test)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/pipeline.py:722, in Pipeline.score(self, X, y, sample_weight)
#     720 if sample_weight is not None:
#     721     score_params["sample_weight"] = sample_weight
# --> 722 return self.steps[-1][1].score(Xt, y, **score_params)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/base.py:722, in RegressorMixin.score(self, X, y, sample_weight)
#     680 """Return the coefficient of determination of the prediction.
#     681
#     682 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     717 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     718 """
#     720 from .metrics import r2_score
# --> 722 y_pred = self.predict(X)
# ...
